# %%
import os
from dotenv import load_dotenv
import requests
import gradio as gr
from pypdf import PdfReader
from openai import OpenAI

# %%
load_dotenv(override=True)
gemini = OpenAI(api_key=os.getenv("API_Key"),base_url="https://generativelanguage.googleapis.com/v1beta/openai/")

# %%
reader = PdfReader("../data/Combined_Profile.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

print(linkedin)
# Out:
# Nishit Gupta - Combined Professional Profile
# Contact:
# A1-1803, Yashwin Encore, Wakad, Pune
# Mobile: 9131023943 / 8989612031
# Email: nishitgupta241@gmail.com
# LinkedIn: linkedin.com/in/nishit-gupta-568571b2
# Professional Summary:
# Experienced SDET / Technical Lead with 9+ years of expertise in automation testing, framework
# development, CI/CD pipeline integration, and Agile delivery. Skilled in Selenium, Katalon Studio,
# Robot Framework, Playwright, and API Automation. Strong experience across Web, Mobile, and
# API testing. Recognized for building scalable frameworks, mentoring teams, and improving test
# productivity.
# Core Competencies:
# - Test Automation: Selenium, Katalon Studio, Robot Framework, Playwright, Appium, Cypress,
# AccelQ
# - Programming: Java, C#, JavaScript, TypeScript, Python, Groovy
# - CI/CD: GitHub Actions, TeamCity, Octopus, Bitbucket
# - Frameworks & Tools: BDD (Cucumber, SpecFlow, NUnit), Mocha, .NET Core, RAGAS, DeepEval
# ...

# %%
with open("../data/summary.txt", "r") as file:
    summary = file.read()

print(summary)
# Out:
# Overall Summary:
# Both files represent your professional profile as a highly experienced SDET / Technical Lead with 9+ years in automation testing, framework development, and CI/CD integrations. You have strong hands-on expertise in Selenium, Katalon Studio, Robot Framework, Playwright, API Testing, CI/CD pipelines, and multiple programming languages including Java, C#, JavaScript, TypeScript, and Python.
#
# Your experience spans Wipro, HCL Technologies, and Capgemini, where you contributed to building automation frameworks, performing API & web automation, supporting cross-functional teams, and mentoring new joiners. You also have several awards for innovation, leadership, and process excellence.
#
# Both documents highlight:
#
# Strong problem-solving and Agile experience
#
# Expertise in BDD frameworks (Cucumber, SpecFlow)
#
# Solid CI/CD knowledge (GitHub Actions, TeamCity, Octopus)
#
# Extensive experience in Web, API, and Mobile automation
#
# ...

# %%
name = "Nishit Gupta"

# %%
system_prompt=""

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
def chat(message, history):
   messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
   response = gemini.chat.completions.create(
       model="gemini-2.5-flash",
       messages=messages,
       max_tokens=500,
       temperature=0.7
   )
   
   return response.choices[0].message.content

# %%
gr.ChatInterface(chat, title="Nishit Gupta's AI Chatbot", description="Ask me anything!").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
